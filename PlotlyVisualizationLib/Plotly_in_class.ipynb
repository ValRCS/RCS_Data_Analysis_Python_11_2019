# %%
import plotly

# %%
# !pip install plotly
# Out:
# ...
#   Running setup.py bdist_wheel for retrying: started
#   Running setup.py bdist_wheel for retrying: finished with status 'done'
#   Stored in directory: C:\Users\Admin\AppData\Local\pip\Cache\wheels\d7\a9\33\acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install cufflinks
# Out:
# ...
#   Running setup.py bdist_wheel for cufflinks: started
#   Running setup.py bdist_wheel for cufflinks: finished with status 'done'
#   Stored in directory: C:\Users\Admin\AppData\Local\pip\Cache\wheels\ef\6a\a4\ff5ceff51314afb5bb24745bf74b51ed4cee53609b66bafa1c
# Successfully built cufflinks
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import plotly

# %%
# get current
plotly.version.stable_semver()
# Out:
# '3.8.0'

# %%
import pandas as pd  
import numpy as np  
# %matplotlib inline

# %%
# we need to import the offline modules for plotly since we want local plots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import seaborn as sb

# seaborn provides some ready made datasets
# https://seaborn.pydata.org/generated/seaborn.load_dataset.html
dataset = sb.load_dataset('tips')

dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.get_dataset_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning:
#
# No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
dataset.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-2864194685e8> in <module>
# ----> 1 dataset.name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %%
dataset2 = dataset[["total_bill", "tip", "size"]]  
dataset2.plot()

# %%
dataset2.plot(kind="box")

# %%
dataset2.iplot()
# Out:
# <div>
#
#
#             <div id="dbe81726-40dd-41fa-8a42-976f2ad80dcb" class="plotly-graph-div"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("dbe81726-40dd-41fa-8a42-976f2ad80dcb")) {
#                     Plotly.newPlot(
#                         'dbe81726-40dd-41fa-8a42-976f2ad80dcb',
# ...

# %%
dataset2.iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="79ec0018-0343-42fe-9b58-0ed3c7d0855b" class="plotly-graph-div"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("79ec0018-0343-42fe-9b58-0ed3c7d0855b")) {
#                     Plotly.newPlot(
#                         '79ec0018-0343-42fe-9b58-0ed3c7d0855b',
# ...

# %%
dataset2.iplot(kind='basic-area')
# Out:
# ---------------------------------------------------------------------------
# PlotlyEmptyDataError                      Traceback (most recent call last)
# <ipython-input-19-69df4e9d04fe> in <module>
# ----> 1 dataset2.iplot(kind='basic-area')
#
# C:\ProgramData\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1215 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
# ...
