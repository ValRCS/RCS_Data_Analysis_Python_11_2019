# %%
import pandas as pd
import folium
from folium import plugins
import os
import json

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.8.3)
# Requirement already satisfied: branca>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.3.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.16.2)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from folium) (1.12.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.10)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->folium) (1.1.1)

# %%
import folium
from folium import plugins

# %%
world = folium.Map()
world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
rcs = folium.Map(location=[56.954778, 24.099106],
                    zoom_start = 18)
rcs
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

# %%
import json

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5AA0-2A07
#
#  Directory of C:\Users\val-p1\Github\RCS_Data_Analysis_Python_09_2019\FoliumGeoLibrary
#
# 10/08/2019  05:12 PM    <DIR>          .
# 10/08/2019  05:12 PM    <DIR>          ..
# 10/08/2019  05:10 PM    <DIR>          .ipynb_checkpoints
# 10/08/2019  02:48 PM        13,750,339 cities.json
# 10/08/2019  02:48 PM           293,956 FOLIUM_in_class_2019.ipynb
# 10/08/2019  05:12 PM           891,997 FOLIUM_in_class_2019_10.2019.ipynb
# 10/08/2019  02:48 PM               419 README.md
# 10/08/2019  02:48 PM            49,467 riga.json
# 10/08/2019  02:48 PM            87,739 us-states.json
# 10/08/2019  02:48 PM               417 US_Unemployment_Oct2012.csv
#                7 File(s)     15,074,334 bytes
#                3 Dir(s)  372,976,390,144 bytes free

# %%
with open('cities.json') as file_in:
    mydata = json.loads(file_in.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-4e9670e0707d> in <module>
#       1 with open('cities.json') as file_in:
# ----> 2     mydata = json.loads(file_in.read())
#
# C:\ProgramData\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1448: character maps to <undefined>

# %%
df = pd.read_json('cities.json', encoding="UTF-8")
#df = pd.read_json('riga.json', encoding="UTF-8")
df[25:40]
# Out:
#    country       lat       lng                  name
# 25      AF  34.34360  67.90567      Wulêswālī Bihsūd
# 26      AF  34.65389  61.19778                Kuhsān
# 27      AF  35.37820  64.77457                  Lāsh
# 28      AF  35.94831  66.42132                Tukzār
# 29      AF  33.32462  68.44068                 Mīray
# 30      AF  36.08352  66.84029             Āq Kupruk
# 31      AF  33.43778  69.02774                Zurmat
# 32      AF  36.52947  71.34410                Zaybāk
# 33      AF  31.98480  65.47360  Zīārat-e Shāh Maqşūd
# 34      AF  34.34264  61.74675            Zindah Jān
# 35      AF  32.84734  68.44573         Zarghūn Shahr
# 36      AF  33.14641  68.79213          Zaṟah Sharan
# 37      AF  30.95962  61.86037                Zaranj
# 38      AF  32.37260  66.17708           Zamtō Kêlay
# 39      AF  37.46572  69.61131          Yangī Qal‘ah

# %%
len(df)
# Out:
# 128769

# %%
df.index = df['name']

# %%
df.head()
# Out:
#                     country       lat      lng                 name
# name
# Sant Julià de Lòria      AD  42.46372  1.49129  Sant Julià de Lòria
# Pas de la Casa           AD  42.54277  1.73361       Pas de la Casa
# Ordino                   AD  42.55623  1.53319               Ordino
# les Escaldes             AD  42.50729  1.53414         les Escaldes
# la Massana               AD  42.54499  1.51483           la Massana

# %%
'Riga' in df.name
# Out:
# True

# %%
# remember without double square brackets we would get a series
df.loc['Riga']
# Out:
# country         LV
# lat         56.946
# lng        24.1059
# name          Riga
# Name: Riga, dtype: object

# %%
df.loc[['Riga']]
# Out:
#      country     lat       lng  name
# name
# Riga      LV  56.946  24.10589  Riga

# %%
Riga = df[df.name == 'Riga']
Riga
# Out:
#      country     lat       lng  name
# name
# Riga      LV  56.946  24.10589  Riga

# %%
df.head(40)
# Out:
#                      country       lat       lng                  name
# name
# Sant Julià de Lòria       AD  42.46372   1.49129   Sant Julià de Lòria
# Pas de la Casa            AD  42.54277   1.73361        Pas de la Casa
# Ordino                    AD  42.55623   1.53319                Ordino
# les Escaldes              AD  42.50729   1.53414          les Escaldes
# la Massana                AD  42.54499   1.51483            la Massana
# Encamp                    AD  42.53474   1.58014                Encamp
# Canillo                   AD  42.56760   1.59756               Canillo
# Arinsal                   AD  42.57205   1.48453               Arinsal
# Andorra la Vella          AD  42.50779   1.52109      Andorra la Vella
# Umm al Qaywayn            AE  25.56473  55.55517        Umm al Qaywayn
# Ras al-Khaimah            AE  25.78953  55.94320        Ras al-Khaimah
# Muzayri‘                  AE  23.14355  53.78810              Muzayri‘
# Murbaḩ                    AE  25.27623  56.36256                Murbaḩ
# Khawr Fakkān              AE  25.33132  56.34199          Khawr Fakkān
# Dubai                     AE  25.06570  55.17128                 Dubai
# Dibba Al-Fujairah         AE  25.59246  56.26176     Dibba Al-Fujairah
# Dibba Al-Hisn             AE  25.61955  56.27291         Dibba Al-Hisn
# Sharjah                   AE  25.33737  55.41206               Sharjah
# Ar Ruways                 AE  24.11028  52.73056             Ar Ruways
# Al Fujayrah               AE  25.11641  56.34141           Al Fujayrah
# Al Ain                    AE  24.19167  55.76056                Al Ain
# Ajman                     AE  25.41111  55.43504                 Ajman
# Adh Dhayd                 AE  25.28812  55.88157             Adh Dhayd
# Abu Dhabi                 AE  24.46667  54.36667             Abu Dhabi
# Zorkot                    AF  33.54149  69.73446                Zorkot
# Wulêswālī Bihsūd          AF  34.34360  67.90567      Wulêswālī Bihsūd
# Kuhsān                    AF  34.65389  61.19778                Kuhsān
# Lāsh                      AF  35.37820  64.77457                  Lāsh
# Tukzār                    AF  35.94831  66.42132                Tukzār
# Mīray                     AF  33.32462  68.44068                 Mīray
# Āq Kupruk                 AF  36.08352  66.84029             Āq Kupruk
# Zurmat                    AF  33.43778  69.02774                Zurmat
# Zaybāk                    AF  36.52947  71.34410                Zaybāk
# Zīārat-e Shāh Maqşūd      AF  31.98480  65.47360  Zīārat-e Shāh Maqşūd
# Zindah Jān                AF  34.34264  61.74675            Zindah Jān
# Zarghūn Shahr             AF  32.84734  68.44573         Zarghūn Shahr
# Zaṟah Sharan              AF  33.14641  68.79213          Zaṟah Sharan
# Zaranj                    AF  30.95962  61.86037                Zaranj
# Zamtō Kêlay               AF  32.37260  66.17708           Zamtō Kêlay
# Yangī Qal‘ah              AF  37.46572  69.61131          Yangī Qal‘ah

# %%
float(Riga.lat)
# Out:
# 56.946

# %%
type(Riga['lat'])
# Out:
# pandas.core.series.Series

# %%
float(Riga['lat'])
# Out:
# 56.946

# %%
def getCity(cityName):
    cityFrame = pd.read_json('cities.json', encoding="UTF-8")
    city = cityFrame[cityFrame.name == cityName]
    return [float(city.lat), float(city.lng)]

# %%
getCity('Riga')
# Out:
# [56.946, 24.10589]

# %%
getCity('Ogre')
# Out:
# [56.8162, 24.61401]

# %%
ogre = folium.Map(location=getCity('ogre'),
                    zoom_start = 15)
ogre
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# we can pass a new dataframe or use the default dataframe df (assuming we already created one)
def getCityDf(cityName, df=df):
    city = df[df.name == cityName]
    if not len(city):
        return [56,24]
    else:
        return [float(city.lat), float(city.lng)]

# %%
badcity=df[df.name == 'badcity']
badcity
# Out:
# Empty DataFrame
# Columns: [country, lat, lng, name]
# Index: []

# %%
len(badcity)
# Out:
# 0

# %%
getCityDf('Badac')
# Out:
# [56, 24]

# %%
df.head()
# Out:
#                     country       lat      lng                 name
# name
# Sant Julià de Lòria      AD  42.46372  1.49129  Sant Julià de Lòria
# Pas de la Casa           AD  42.54277  1.73361       Pas de la Casa
# Ordino                   AD  42.55623  1.53319               Ordino
# les Escaldes             AD  42.50729  1.53414         les Escaldes
# la Massana               AD  42.54499  1.51483           la Massana

# %%
getCity('Riga')
# Out:
# [56.946, 24.10589]

# %%
getCityDf('Riga', df)
# Out:
# [56.946, 24.10589]

# %%
getCityDf('Ogre')
# Out:
# [56.8162, 24.61401]

# %%
gCity = getCityDf

# %%
tallin = folium.Map(location=getCityDf('Tallinn'), zoom_start=10)
tallin
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gCity('Tallinn')
# Out:
# [59.43696, 24.75353]

# %%
ogre = folium.Map(location=gCity('Ogre'), zoom_start = 10)
ogre
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tukums = folium.Map(location=gCity('Tukums'),
                        tiles = "Stamen Terrain",
                        zoom_start = 15)
tukums
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
clean_map = folium.Map()
clean_map

# %%
latvijas_universitate = folium.Map(location=[56.95080,24.11650],
                        tiles = "Stamen Toner",
                        zoom_start = 20)
latvijas_universitate

# %%
folium.Marker([56.954778, 24.099106], tooltip='RCS tooltip',popup='RCS popup').add_to(rcs)
rcs
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latvijas_universitate = folium.Map(location=[56.95080,24.11650],
                        width=500, height=500, #var nodefinēt dimensijas
                        zoom_start = 20)

latvijas_universitate

folium.Marker([56.95080,24.11650], tooltip='LU',popup='Latvijas universitāte').add_to(ogre)
ogre
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# we can change location and zoom later on as in the example below
world.zoom_start=8
world.location=gCity('Riga')
world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df[df.name == 'London']
# Out:
#        country       lat        lng    name
# name
# London      CA  42.98339  -81.23304  London
# London      GB  51.50853   -0.12574  London
# London      US  35.32897  -93.25296  London
# London      US  37.12898  -84.08326  London
# London      US  39.88645  -83.44825  London
# London      US  36.47606 -119.44318  London

# %%
lvcities = df[df['country'] == 'LV']
lvcities
# Out:
#              country       lat       lng          name
# name
# Valmiera          LV  57.54108  25.42751      Valmiera
# Zilupe            LV  56.38616  28.12165        Zilupe
# Zelmeņi           LV  56.45167  23.35194       Zelmeņi
# Viļaka            LV  57.18458  27.67220        Viļaka
# Viļāni            LV  56.55253  26.92449        Viļāni
# Viesīte           LV  56.34751  25.55514       Viesīte
# Vecumnieki        LV  56.60608  24.52232    Vecumnieki
# Ventspils         LV  57.38988  21.57288     Ventspils
# Vecvārkava        LV  56.19838  26.50811    Vecvārkava
# Vecpiebalga       LV  57.06090  25.81624   Vecpiebalga
# Varakļāni         LV  56.60826  26.75377     Varakļāni
# Vangaži           LV  57.09358  24.54468       Vangaži
# Valka             LV  57.77520  26.01013         Valka
# Valdemārpils      LV  57.37068  22.59188  Valdemārpils
# Vaiņode           LV  56.41848  21.85405       Vaiņode
# Ulbroka           LV  56.93630  24.30387       Ulbroka
# Tukums            LV  56.96764  23.15554        Tukums
# Tīreļi            LV  56.83991  23.58902        Tīreļi
# Tērvete           LV  56.47989  23.38895       Tērvete
# Talsi             LV  57.24562  22.58137         Talsi
# Strenči           LV  57.62574  25.68535       Strenči
# Stende            LV  57.14497  22.53482        Stende
# Stalbe            LV  57.37065  25.03106        Stalbe
# Staicele          LV  57.83639  24.75000      Staicele
# Smiltene          LV  57.42444  25.90164      Smiltene
# Smārde            LV  56.95420  23.33736        Smārde
# Skrunda           LV  56.67749  22.01649       Skrunda
# Skrīveri          LV  56.64500  25.12058      Skrīveri
# Sigulda           LV  57.15375  24.85953       Sigulda
# Seda              LV  57.65042  25.75089          Seda
# ...              ...       ...       ...           ...
# Engure            LV  57.16061  23.22527        Engure
# Dundaga           LV  57.50498  22.35041       Dundaga
# Drabeši           LV  57.24316  25.27748       Drabeši
# Dobele            LV  56.62372  23.27510        Dobele
# Daugavpils        LV  55.88333  26.53333    Daugavpils
# Daugavgrīva       LV  57.04315  24.03613   Daugavgrīva
# Dagda             LV  56.09512  27.53723         Dagda
# Cesvaine          LV  56.96754  26.30764      Cesvaine
# Cēsis             LV  57.31188  25.27456         Cēsis
# Carnikava         LV  57.12935  24.28423     Carnikava
# Brocēni           LV  56.67890  22.56945       Brocēni
# Bolderaja         LV  57.03132  24.05571     Bolderaja
# Berģi             LV  56.98639  24.29917         Berģi
# Bauska            LV  56.40794  24.19443        Bauska
# Balvi             LV  57.13130  27.26583         Balvi
# Baltinava         LV  56.94394  27.64401     Baltinava
# Baldone           LV  56.74451  24.40078       Baldone
# Auce              LV  56.45981  22.90169          Auce
# Ape               LV  57.53928  26.69291           Ape
# Alūksne           LV  57.42162  27.04662       Alūksne
# Alsunga           LV  56.98194  21.55938       Alsunga
# Aloja             LV  57.76723  24.87743         Aloja
# Aknīste           LV  56.16152  25.74783       Aknīste
# Aizpute           LV  56.72108  21.60156       Aizpute
# Aizkraukle        LV  56.60477  25.25534    Aizkraukle
# Ainaži            LV  57.86348  24.35853        Ainaži
# Aglona            LV  56.13333  27.01667        Aglona
# Ādaži             LV  57.07045  24.33713         Ādaži
# Baloži            LV  56.87643  24.11825        Baloži
# Mārupe            LV  56.90544  24.05113        Mārupe
#
# [134 rows x 4 columns]

# %%
#we can sort by index
lvcities.sort_index()
# Out:
#              country       lat       lng          name
# name
# Aglona            LV  56.13333  27.01667        Aglona
# Ainaži            LV  57.86348  24.35853        Ainaži
# Aizkraukle        LV  56.60477  25.25534    Aizkraukle
# Aizpute           LV  56.72108  21.60156       Aizpute
# Aknīste           LV  56.16152  25.74783       Aknīste
# Aloja             LV  57.76723  24.87743         Aloja
# Alsunga           LV  56.98194  21.55938       Alsunga
# Alūksne           LV  57.42162  27.04662       Alūksne
# Ape               LV  57.53928  26.69291           Ape
# Auce              LV  56.45981  22.90169          Auce
# Baldone           LV  56.74451  24.40078       Baldone
# Baloži            LV  56.87643  24.11825        Baloži
# Baltinava         LV  56.94394  27.64401     Baltinava
# Balvi             LV  57.13130  27.26583         Balvi
# Bauska            LV  56.40794  24.19443        Bauska
# Berģi             LV  56.98639  24.29917         Berģi
# Bolderaja         LV  57.03132  24.05571     Bolderaja
# Brocēni           LV  56.67890  22.56945       Brocēni
# Carnikava         LV  57.12935  24.28423     Carnikava
# Cesvaine          LV  56.96754  26.30764      Cesvaine
# Cibla             LV  56.54980  27.88370         Cibla
# Cēsis             LV  57.31188  25.27456         Cēsis
# Dagda             LV  56.09512  27.53723         Dagda
# Daugavgrīva       LV  57.04315  24.03613   Daugavgrīva
# Daugavpils        LV  55.88333  26.53333    Daugavpils
# Dobele            LV  56.62372  23.27510        Dobele
# Drabeši           LV  57.24316  25.27748       Drabeši
# Dundaga           LV  57.50498  22.35041       Dundaga
# Engure            LV  57.16061  23.22527        Engure
# Garkalne          LV  57.04486  24.41951      Garkalne
# ...              ...       ...       ...           ...
# Smiltene          LV  57.42444  25.90164      Smiltene
# Smārde            LV  56.95420  23.33736        Smārde
# Staicele          LV  57.83639  24.75000      Staicele
# Stalbe            LV  57.37065  25.03106        Stalbe
# Stende            LV  57.14497  22.53482        Stende
# Strenči           LV  57.62574  25.68535       Strenči
# Talsi             LV  57.24562  22.58137         Talsi
# Tukums            LV  56.96764  23.15554        Tukums
# Tērvete           LV  56.47989  23.38895       Tērvete
# Tīreļi            LV  56.83991  23.58902        Tīreļi
# Ulbroka           LV  56.93630  24.30387       Ulbroka
# Vaiņode           LV  56.41848  21.85405       Vaiņode
# Valdemārpils      LV  57.37068  22.59188  Valdemārpils
# Valka             LV  57.77520  26.01013         Valka
# Valmiera          LV  57.54108  25.42751      Valmiera
# Vangaži           LV  57.09358  24.54468       Vangaži
# Varakļāni         LV  56.60826  26.75377     Varakļāni
# Vecpiebalga       LV  57.06090  25.81624   Vecpiebalga
# Vecumnieki        LV  56.60608  24.52232    Vecumnieki
# Vecvārkava        LV  56.19838  26.50811    Vecvārkava
# Ventspils         LV  57.38988  21.57288     Ventspils
# Viesīte           LV  56.34751  25.55514       Viesīte
# Viļaka            LV  57.18458  27.67220        Viļaka
# Viļāni            LV  56.55253  26.92449        Viļāni
# Zelmeņi           LV  56.45167  23.35194       Zelmeņi
# Zilupe            LV  56.38616  28.12165        Zilupe
# Ādaži             LV  57.07045  24.33713         Ādaži
# Ērgļi             LV  56.89752  25.63668         Ērgļi
# Ķegums            LV  56.74510  24.72439        Ķegums
# Ķekava            LV  56.82662  24.23000        Ķekava
#
# [134 rows x 4 columns]

# %%
lvcities.sort_values(['lat']).tail()
# Out:
#           country       lat       lng       name
# name
# Staicele       LV  57.83639  24.75000   Staicele
# Mazsalaca      LV  57.86329  25.05475  Mazsalaca
# Ainaži         LV  57.86348  24.35853     Ainaži
# Naukšēni       LV  57.88349  25.45609   Naukšēni
# Rūjiena        LV  57.89752  25.33155    Rūjiena

# %%
df.head()
# Out:
#                     country       lat      lng                 name
# name
# Sant Julià de Lòria      AD  42.46372  1.49129  Sant Julià de Lòria
# Pas de la Casa           AD  42.54277  1.73361       Pas de la Casa
# Ordino                   AD  42.55623  1.53319               Ordino
# les Escaldes             AD  42.50729  1.53414         les Escaldes
# la Massana               AD  42.54499  1.51483           la Massana

# %%
lvcities = df[df.country == 'LV']
lvcities.head()
# Out:
#          country       lat       lng      name
# name
# Valmiera      LV  57.54108  25.42751  Valmiera
# Zilupe        LV  56.38616  28.12165    Zilupe
# Zelmeņi       LV  56.45167  23.35194   Zelmeņi
# Viļaka        LV  57.18458  27.67220    Viļaka
# Viļāni        LV  56.55253  26.92449    Viļāni

# %%
lvcities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 134 entries, Valmiera to Mārupe
# Data columns (total 4 columns):
# country    134 non-null object
# lat        134 non-null float64
# lng        134 non-null float64
# name       134 non-null object
# dtypes: float64(2), object(2)
# memory usage: 5.2+ KB

# %%
lvcities.describe()
# Out:
#               lat         lng
# count  134.000000  134.000000
# mean    56.907784   24.634215
# std      0.455718    1.747996
# min     55.883330   21.012870
# 25%     56.585712   23.619960
# 50%     56.920870   24.696805
# 75%     57.179972   25.760895
# max     57.897520   28.121650

# %%
lvcities.head()
# Out:
#          country       lat       lng      name
# name
# Valmiera      LV  57.54108  25.42751  Valmiera
# Zilupe        LV  56.38616  28.12165    Zilupe
# Zelmeņi       LV  56.45167  23.35194   Zelmeņi
# Viļaka        LV  57.18458  27.67220    Viļaka
# Viļāni        LV  56.55253  26.92449    Viļāni

# %%
zilupe = lvcities.iloc[1]
zilupe
# Out:
# country         LV
# lat        56.3862
# lng        28.1216
# name        Zilupe
# Name: Zilupe, dtype: object

# %%
zilupe.name, float(zilupe.lat), float(zilupe.lng)
# Out:
# ('Zilupe', 56.38616, 28.12165)

# %%
def createCitiesMap(countrycode='LV', filename='cities.json', addToolTip=False):
    df = pd.read_json(filename, encoding="UTF-8")
    # filter cities by country code
    cities = df[df.country == countrycode]
    # create a new Folium Map
    newmap = folium.Map(location=[(cities.lat.max()+cities.lat.min())/2, (cities.lng.max()+cities.lng.min())/2], zoom_start = 7)
    #iterrows
    # https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
    for index, city in cities.iterrows():
        if addToolTip:
            mytooltip = str(city['name'])
        else:
            mytooltip = None
        folium.Marker([float(city.lat), float(city.lng)], tooltip = mytooltip).add_to(newmap)
    return newmap

# %%
# we can change zoom after the fact
latvija.zoom_start = 7
latvija
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latvija = createCitiesMap(addToolTip=True)
latvija
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lt = createCitiesMap(countrycode='LT',addToolTip=True)
lt
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
eecities = df[df.country == 'EE']
eecities
# Out:
#              country       lat       lng          name
# name
# Vändra            EE  58.64806  25.03611        Vändra
# Võru              EE  57.83389  27.01944          Võru
# Voka              EE  59.40776  27.58263          Voka
# Võhma             EE  58.62833  25.54833         Võhma
# Vinni             EE  59.29583  26.43222         Vinni
# Viljandi          EE  58.36389  25.59000      Viljandi
# Viiratsi          EE  58.36000  25.63722      Viiratsi
# Viimsi            EE  59.50502  24.84807        Viimsi
# Värska            EE  57.95806  27.63806        Värska
# Vana-Antsla       EE  57.86611  26.53222   Vana-Antsla
# Valga             EE  57.77781  26.04730         Valga
# Väike-Maarja      EE  59.12639  26.25000  Väike-Maarja
# Vaida             EE  59.28546  24.97897         Vaida
# Uulu              EE  58.28361  24.58722          Uulu
# Uuemõisa          EE  58.93944  23.58944      Uuemõisa
# Ülenurme          EE  58.31620  26.72517      Ülenurme
# Türi              EE  58.80861  25.43250          Türi
# Turba             EE  59.08306  24.22500         Turba
# Tõrva             EE  58.00278  25.93500         Tõrva
# Tootsi            EE  58.57806  24.79250        Tootsi
# Toila             EE  59.42127  27.50807         Toila
# Tehumardi         EE  58.18027  22.24646     Tehumardi
# Tartu             EE  58.38062  26.72509         Tartu
# Tapa              EE  59.26056  25.95861          Tapa
# Tamsalu           EE  59.15861  26.11528       Tamsalu
# Tallinn           EE  59.43696  24.75353       Tallinn
# Taebla            EE  58.95389  23.75222        Taebla
# Tabasalu          EE  59.42607  24.55330      Tabasalu
# Suure-Jaani       EE  58.53611  25.47056   Suure-Jaani
# Sindi             EE  58.40056  24.66750         Sindi
# ...              ...       ...       ...           ...
# Kiili             EE  59.30775  24.83776         Kiili
# Keila             EE  59.30361  24.41306         Keila
# Kehtna            EE  58.93028  24.87806        Kehtna
# Kehra             EE  59.33611  25.32111         Kehra
# Kärdla            EE  58.99778  22.74917        Kärdla
# Kanepi            EE  57.98306  26.75639        Kanepi
# Kallaste          EE  58.66312  27.16164      Kallaste
# Kadrina           EE  59.33472  26.14500       Kadrina
# Jüri              EE  59.35417  24.89417          Jüri
# Jõhvi             EE  59.35917  27.42111         Jõhvi
# Jõgeva            EE  58.74667  26.39389        Jõgeva
# Järvakandi        EE  58.77889  24.82583    Järvakandi
# Järva-Jaani       EE  59.03861  25.88639   Järva-Jaani
# Iisaku            EE  59.10139  27.30806        Iisaku
# Hullo             EE  58.99004  23.24441         Hullo
# Haljala           EE  59.43361  26.26139       Haljala
# Haapsalu          EE  58.94306  23.54139      Haapsalu
# Haabneeme         EE  59.51358  24.82225     Haabneeme
# Elva              EE  58.22250  26.42111          Elva
# Audru             EE  58.40861  24.37389         Audru
# Aseri             EE  59.45056  26.86750         Aseri
# Aruküla           EE  59.36686  25.07618       Aruküla
# Antsla            EE  57.82556  26.54056        Antsla
# Alatskivi         EE  58.59806  27.13361     Alatskivi
# Abja-Paluoja      EE  58.12528  25.34972  Abja-Paluoja
# Vaiatu            EE  59.35556  25.99528        Vaiatu
# Sõmeru            EE  59.36111  26.43750        Sõmeru
# Harku             EE  59.38641  24.57176         Harku
# Laagri            EE  59.35083  24.61418        Laagri
# Viimsi            EE  59.50086  24.86254        Viimsi
#
# [114 rows x 4 columns]

# %%
ncities = df[df.country == 'NO']
len(ncities)
# Out:
# 541

# %%
rcities = df[df.country == 'RU']
len(rcities)
# Out:
# 4642

# %%
estonia = createCitiesMap("EE", addToolTip=True)
estonia
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mn = createCitiesMap('MN')
mn
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
jp = createCitiesMap("JP")
jp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lietuva.lat.max(),lietuva.lat.min()

# %%
lietuva = df[df.country == "LT"]
lietuva.head()

# %%
df.head()

# %%
estonia = createCitiesMap('EE')

# %%
estonia

# %%
#Adding cities to map
for index, city in lvcities.iterrows():
    folium.Marker([float(city.lat), float(city.lng)]).add_to(clean_map)

# %%
clean_map

# %%
clean_map.location = getCity('Ogre')
clean_map.zoom_start = 7
clean_map

# %%
clean_map.zoom_start = 7
clean_map

# %%
latvijas_universitate = folium.Map(location=[56.9504,24.11650],
                        #tiles = "Stamen Watercolor",
                        zoom_start = 20)
# Parasts marķieris, zaļš
folium.Marker([56.95080,24.11650],
              popup='Latvijas universitāte',
              icon=folium.Icon(color='green')
             ).add_to(latvijas_universitate)

# Apaļš marķieris
folium.CircleMarker([56.95,24.1174],
                    radius=100,
                    popup='Mūzikas akadēmija',
                    color='red',
                    ).add_to(latvijas_universitate)
folium.Circle(
      location=[56.955,24.1134],
      popup='Random',
      radius=25,
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(latvijas_universitate)

# Interactive marker
latvijas_universitate.add_child(folium.ClickForMarker(popup="Galapunkts"))

latvijas_universitate
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
centrs = folium.Map(location=[56.9514934,24.1135],
                        tiles = "Stamen Toner", #Mapbox Bright
                        zoom_start = 17)

folium.Marker([56.9514934,24.1135],
              popup='Brīvības piemineklis',
              icon=folium.Icon(color='green')
             ).add_to(centrs)
folium.Marker([56.95080,24.11650], 
              popup='Latvijas Universitāte',
              icon=folium.Icon(color='blue',icon='university', prefix='fa') 
             ).add_to(centrs)

folium.Marker([56.9514934,24.1111156], 
              popup='Bastejkalns',
              icon=folium.Icon(color='red',icon='bicycle', prefix='fa')
             ).add_to(centrs)
centrs = folium.Map(location=[56.9514934,24.1135],
                        tiles = "Stamen Toner", #Mapbox Bright
                        zoom_start = 17)

folium.Marker([56.9514934,24.1135],
              popup='Brīvības piemineklis',
              icon=folium.Icon(color='green')
             ).add_to(centrs)
folium.Marker([56.95080,24.11650], 
              popup='Latvijas Universitāte',
              icon=folium.Icon(color='blue',icon='university', prefix='fa') 
             ).add_to(centrs)

folium.Marker([56.950934,24.1114156], 
              popup='Peldvieta',
              icon=folium.Icon(color='blue',icon='road', prefix='fa')
             ).add_to(centrs)

centrs

centrs
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.plugins import MiniMap

latvia = folium.Map(location=(57,25), zoom_start=6,width=500, height=500)

minimap = MiniMap()
latvia.add_child(minimap)
latvia
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
coordinates = [
[56.95080,24.11650],
[56.9506724,24.11533],
[56.9515315,24.1143683],
[56.9518371,24.1138815],
[56.9515036,24.1135815]]

centrs = folium.Map(location=[56.9514934,24.1135],
                        zoom_start = 17)

path = folium.PolyLine(
    [coordinates]
).add_to(centrs)

# Create the map and add the line
folium.Marker([56.95080,24.11650], popup='Latvijas universitāte', icon=folium.Icon(color='red')).add_to(centrs)
folium.Marker([56.9514934,24.1135],
              popup='Brīvības piemineklis',
              icon=folium.Icon(color='red')
             ).add_to(centrs)


plugins.PolyLineTextPath(
    path,
    'Uz brīvības pieminekli',
    offset=-5
).add_to(centrs)

centrs

# %%
#https://www.openstreetmap.org/relation/1554509
#http://polygons.openstreetmap.fr/
riga = os.path.join('riga.json')
geo_json_data = json.load(open(riga))

# %%
len(geo_json_data)
# Out:
# 2

# %%
type(geo_json_data)
# Out:
# dict

# %%
geo_json_data.keys()
# Out:
# dict_keys(['type', 'geometries'])

# %%
geo = geo_json_data['geometries']
len(geo)
# Out:
# 1

# %%
# for some reason json data has unused lists 2 levels deep
coor = geo_json_data['geometries'][0]['coordinates'][0][0]
len(coor)
# Out:
# 1349

# %%
coor[:5]
# Out:
# [[23.9323704, 57.0088701],
#  [23.9333454, 57.0097246],
#  [23.9336425, 57.0098834],
#  [23.934583, 57.0103859],
#  [23.9357981, 57.0116981]]

# %%
riga = folium.Map(location=[56.9514934,24.1135],
                        zoom_start = 10)

folium.GeoJson(
    geo_json_data,
    style_function=lambda feature: {
        'fillColor': 'blue',
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(riga)

riga.save(os.path.join('Colormaps_0.html')) #saglabā rezultātu html failā
riga
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([30, 0], zoom_start=3)

wind_locations = [
    [59.35560, -31.992190],
    [55.178870, -42.89062],
    [47.754100, -43.94531],
    [38.272690, -37.96875],
    [27.059130, -41.13281],
    [16.299050, -36.56250],
    [8.4071700, -30.23437],
    [1.0546300, -22.50000],
    [-8.754790, -18.28125],
    [-21.61658, -20.03906],
    [-31.35364, -24.25781],
    [-39.90974, -30.93750],
    [-43.83453, -41.13281],
    [-47.75410, -49.92187],
    [-50.95843, -54.14062],
    [-55.97380, -56.60156]
]

wind_line = folium.PolyLine(
    wind_locations,
    weight=15,
    color='#8EE9FF'
).add_to(m)

attr = {'fill': '#007DEF', 'font-weight': 'bold', 'font-size': '24'}

plugins.PolyLineTextPath(
    wind_line,
    ') ',
    repeat=True,
    offset=7,
    attributes=attr
).add_to(m)

danger_line = folium.PolyLine(
    [[-40.311, -31.952],
     [-12.086, -18.727]],
    weight=10,
    color='orange',
    opacity=0.8
).add_to(m)

attr = {'fill': 'red'}

plugins.PolyLineTextPath(
    danger_line,
    '\u25BA',
    repeat=True,
    offset=6,
    attributes=attr
).add_to(m)

plane_line = folium.PolyLine(
    [[-49.38237, -37.26562],
     [-1.75754, -14.41406],
     [51.61802, -23.20312]],
    weight=1,
    color='black'
).add_to(m)

attr = {'font-weight': 'bold', 'font-size': '24'}

plugins.PolyLineTextPath(
    plane_line,
    '\u2708     ',
    repeat=True,
    offset=8,
    attributes=attr
).add_to(m)


line_to_new_delhi = folium.PolyLine(
    [[46.67959447, 3.33984375],
     [46.5588603, 29.53125],
     [42.29356419, 51.328125],
     [35.74651226, 68.5546875],
     [28.65203063, 76.81640625]]
).add_to(m)


line_to_hanoi = folium.PolyLine(
    [[28.76765911, 77.60742188],
     [27.83907609, 88.72558594],
     [25.68113734, 97.3828125],
     [21.24842224, 105.77636719]]
).add_to(m)


plugins.PolyLineTextPath(
    line_to_new_delhi,
    'To New Delhi',
    offset=-5
).add_to(m)


plugins.PolyLineTextPath(
    line_to_hanoi,
    'To Hanoi',
    offset=-5
).add_to(m)

m.save(os.path.join('Polyline_text_path.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
us_states = os.path.join('us-states.json')
geo_json_data = json.load(open(us_states))

unemployment = pd.read_csv('US_Unemployment_Oct2012.csv')

unemployment_dict = unemployment.set_index('State')['Unemployment']

# %%
def my_color_function(feature):
    "Zemās vērtības - zaļas. Augstās - sarkanas"
    if unemployment_dict[feature['id']] > 6.5:
        return '#ff0000'
    else:
        return '#008000'

# %%
m = folium.Map([43, -100], tiles='cartodbpositron', zoom_start=4)

folium.GeoJson(
    geo_json_data,
    style_function=lambda feature: {
        'fillColor': my_color_function(feature),
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(m)

m.save(os.path.join('Colormaps_0.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import branca.colormap as cm

linear = cm.LinearColormap(
    ['green', 'yellow', 'red'],
    vmin=3, vmax=10
)

linear

# %%
m = folium.Map([43, -100], tiles='cartodbpositron', zoom_start=4)

folium.GeoJson(
    geo_json_data,
    style_function=lambda feature: {
        'fillColor': linear(unemployment_dict[feature['id']]),
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(m)

m.save(os.path.join('Colormaps_2.html'))

m

# %%
lcities = pd.read_html('https://en.wikipedia.org/wiki/List_of_cities_and_towns_in_Latvia')
len(lcities)
# Out:
# 8

# %%
lcities[0]
# Out:
#                                    City  Population (2011 census)[2]  \
# 0  Daugavpils pronunciation (help·info)                        93312
# 1   Jēkabpils pronunciation (help·info)                        24635
# 2     Jelgava pronunciation (help·info)                        59511
# 3     Jūrmala pronunciation (help·info)                        50840
# 4     Liepāja pronunciation (help·info)                        76731
# 5     Rēzekne pronunciation (help·info)                        32328
# 6        Rīga pronunciation (help·info)                       658640
# 7    Valmiera pronunciation (help·info)                        25130
# 8   Ventspils pronunciation (help·info)                        38750
#
#    Population (2019)[3]
# 0                 82604
# 1                 22076
# 2                 55972
# 3                 49325
# 4                 68945
# 5                 27820
# 6                632614
# 7                 23125
# 8                 34377

# %%
lcities[1]
# Out:
#                                       Town  Population (2010)[2]  \
# 0         Ainaži pronunciation (help·info)                  1008
# 1     Aizkraukle pronunciation (help·info)                  8709
# 2        Aizpute pronunciation (help·info)                  5104
# 3        Aknīste pronunciation (help·info)                  1224
# 4          Aloja pronunciation (help·info)                  1353
# 5        Alūksne pronunciation (help·info)                  8900
# 6            Ape pronunciation (help·info)                  1083
# 7           Auce pronunciation (help·info)                  3076
# 8        Baldone pronunciation (help·info)                  2399
# 9         Baloži pronunciation (help·info)                  5665
# 10         Balvi pronunciation (help·info)                  7906
# 11        Bauska pronunciation (help·info)                 10060
# 12       Brocēni pronunciation (help·info)                  3411
# 13         Cēsis pronunciation (help·info)                 18021
# 14      Cesvaine pronunciation (help·info)                  1668
# 15         Dagda pronunciation (help·info)                  2502
# 16        Dobele pronunciation (help·info)                 11152
# 17         Durbe pronunciation (help·info)                   620
# 18       Grobiņa pronunciation (help·info)                  4218
# 19       Gulbene pronunciation (help·info)                  8807
# 20       Ikšķile pronunciation (help·info)                  4052
# 21       Ilūkste pronunciation (help·info)                  2856
# 22   Jaunjelgava pronunciation (help·info)                  2246
# 23       Kandava pronunciation (help·info)                  4225
# 24       Kārsava pronunciation (help·info)                  2420
# 25      Krāslava pronunciation (help·info)                 10160
# 26       Kuldīga pronunciation (help·info)                 12755
# 27        Ķegums pronunciation (help·info)                  2487
# 28     Lielvārde pronunciation (help·info)                  6837
# 29       Līgatne pronunciation (help·info)                  1239
# ..                                     ...                   ...
# 37        Olaine pronunciation (help·info)                 12667
# 38     Pāvilosta pronunciation (help·info)                  1134
# 39       Piltene pronunciation (help·info)                  1053
# 40      Pļaviņas pronunciation (help·info)                  3692
# 41        Preiļi pronunciation (help·info)                  7970
# 42      Priekule pronunciation (help·info)                  2441
# 43       Rūjiena pronunciation (help·info)                  3377
# 44        Sabile pronunciation (help·info)                  1404
# 45    Salacgrīva pronunciation (help·info)                  3281
# 46     Salaspils pronunciation (help·info)                 18159
# 47        Saldus pronunciation (help·info)                 12306
# 48    Saulkrasti pronunciation (help·info)                  3299
# 49          Seda pronunciation (help·info)                  1547
# 50       Sigulda pronunciation (help·info)                 11168
# 51       Skrunda pronunciation (help·info)                  2468
# 52      Smiltene pronunciation (help·info)                  5763
# 53      Staicele pronunciation (help·info)                  1152
# 54        Stende pronunciation (help·info)                  1868
# 55       Strenči pronunciation (help·info)                  1404
# 56        Subate pronunciation (help·info)                   749
# 57         Talsi pronunciation (help·info)                 11201
# 58        Tukums pronunciation (help·info)                 19961
# 59  Valdemārpils pronunciation (help·info)                  1396
# 60         Valka pronunciation (help·info)                  6047
# 61       Vangaži pronunciation (help·info)                  3999
# 62     Varakļāni pronunciation (help·info)                  2106
# 63       Viesīte pronunciation (help·info)                  1902
# 64        Viļaka pronunciation (help·info)                  1525
# 65        Viļāni pronunciation (help·info)                  3468
# 66        Zilupe pronunciation (help·info)                  1746
#
#     Population (2018)[3]           Municipality[1]
# 0                    787   Salacgrīva Municipality
# 1                   7489   Aizkraukle Municipality
# 2                   4443      Aizpute Municipality
# 3                   1078      Aknīste Municipality
# 4                   1197        Aloja Municipality
# 5                   7555      Alūksne Municipality
# 6                    907          Ape Municipality
# 7                   2640         Auce Municipality
# 8                   3966      Baldone Municipality
# 9                   6529       Ķekava Municipality
# 10                  6696        Balvi Municipality
# 11                  8988       Bauska Municipality
# 12                  3117      Brocēni Municipality
# 13                 16888        Cēsis Municipality
# 14                  1443     Cesvaine Municipality
# 15                  2108        Dagda Municipality
# 16                  9702       Dobele Municipality
# 17                   542        Durbe Municipality
# 18                  3861      Grobiņa Municipality
# 19                  7779      Gulbene Municipality
# 20                  7359      Ikšķile Municipality
# 21                  2502      Ilūkste Municipality
# 22                  1999  Jaunjelgava Municipality
# 23                  3831      Kandava Municipality
# 24                  2105      Kārsava Municipality
# 25                  8653     Krāslava Municipality
# 26                 11275      Kuldīga Municipality
# 27                  2271       Ķegums Municipality
# 28                  6369    Lielvārde Municipality
# 29                  1094      Līgatne Municipality
# ..                   ...                       ...
# 37                 11342       Olaine Municipality
# 38                   980    Pāvilosta Municipality
# 39                   904    Ventspils Municipality
# 40                  3248     Pļaviņas Municipality
# 41                  6817       Preiļi Municipality
# 42                  2091     Priekule Municipality
# 43                  2912      Rūjiena Municipality
# 44                  1552        Talsi Municipality
# 45                  2823   Salacgrīva Municipality
# 46                 18698    Salaspils Municipality
# 47                 10869       Saldus Municipality
# 48                  3176   Saulkrasti Municipality
# 49                  1248      Strenči Municipality
# 50                 11191      Sigulda Municipality
# 51                  2118      Skrunda Municipality
# 52                  5349     Smiltene Municipality
# 53                   951        Aloja Municipality
# 54                  1743        Talsi Municipality
# 55                  1140      Strenči Municipality
# 56                   663      Ilūkste Municipality
# 57                 10070        Talsi Municipality
# 58                 18414       Tukums Municipality
# 59                  1343        Talsi Municipality
# 60                  5181        Valka Municipality
# 61                  3649    Inčukalns Municipality
# 62                  1897    Varakļāni Municipality
# 63                  1615      Viesīte Municipality
# 64                  1364       Viļaka Municipality
# 65                  3035       Viļāni Municipality
# 66                  1511       Zilupe Municipality
#
# [67 rows x 4 columns]

# %%
cities = lcities[1]
cities.head()
# Out:
#                                    Town  Population (2010)[2]  \
# 0      Ainaži pronunciation (help·info)                  1008
# 1  Aizkraukle pronunciation (help·info)                  8709
# 2     Aizpute pronunciation (help·info)                  5104
# 3     Aknīste pronunciation (help·info)                  1224
# 4       Aloja pronunciation (help·info)                  1353
#
#    Population (2018)[3]          Municipality[1]
# 0                   787  Salacgrīva Municipality
# 1                  7489  Aizkraukle Municipality
# 2                  4443     Aizpute Municipality
# 3                  1078     Aknīste Municipality
# 4                  1197       Aloja Municipality

# %%
# we can an anonymous lambda function to indicate
# what process to perform on each cell in Town column
cities['Name']=cities['Town'].apply(lambda st: st.split()[0])
cities.head()
# Out:
#                                    Town  Population (2010)[2]  \
# 0      Ainaži pronunciation (help·info)                  1008
# 1  Aizkraukle pronunciation (help·info)                  8709
# 2     Aizpute pronunciation (help·info)                  5104
# 3     Aknīste pronunciation (help·info)                  1224
# 4       Aloja pronunciation (help·info)                  1353
#
#    Population (2018)[3]          Municipality[1]        Name
# 0                   787  Salacgrīva Municipality      Ainaži
# 1                  7489  Aizkraukle Municipality  Aizkraukle
# 2                  4443     Aizpute Municipality     Aizpute
# 3                  1078     Aknīste Municipality     Aknīste
# 4                  1197       Aloja Municipality       Aloja

# %%
cities['Town'][0].split()[0]
# Out:
# 'Ainaži'

# %%
lcities[2].head()
# Out:
#     0                                                  1
# 0 NaN  Wikimedia Commons has media related to Cities ...

# %%
lcities[3].head()
# Out:
#   vteDefunct districts and major cities of Latvia  \
# 0                               Defunct districts
# 1                                    Major cities
#
#    vteDefunct districts and major cities of Latvia.1
# 0  Aizkraukle District Alūksne District Balvi Dis...
# 1  Daugavpils Jelgava Jūrmala Liepāja Rēzekne Rig...
